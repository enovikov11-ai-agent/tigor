# %%
# %%time
from utils_search import Chat, Combine
chat = Chat(combines = [Combine.consecutive(n) for n in [1, 2, 5, 10, 40, 1000]])
chat
# Out:
# CPU times: user 4.3 s, sys: 652 ms, total: 4.95 s
# Wall time: 3.11 s
# Index complexity tokens(M): 12.09, price: $1.21, time: 14 minutes

# %%
# chat.build()
# print(chat.search("1234", count = 3))
# chat.print_db_stats()
# chat.export("x1000")
