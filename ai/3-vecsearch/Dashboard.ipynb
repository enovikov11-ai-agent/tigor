# %%
# from utils_dashboard import chat, is_worktime, uniqs, plot_worktimes

# chat_work = [m for m in chat if is_worktime(m)]

# display(f"В рабочее время постят {100*len(chat_work)/len(chat):.2f}% сообщений")

# print("chat")
# display(uniqs([m.get('from') for m in chat]))

# print("chat_work")
# display(uniqs([m.get('from') for m in chat_work]))

# plot_worktimes(chat, chat_work)
