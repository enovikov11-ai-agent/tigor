# %%
import requests, time

key = "&apiKey=***REMOVED***"
base = "https://api.polygon.io/v3/reference/options/contracts?underlying_ticker=XSP&contract_type=put&expiration_date.gt=2023-10-25&expiration_date.lt=2025-10-25&expired=true&order=asc&limit=1000&sort=ticker"
