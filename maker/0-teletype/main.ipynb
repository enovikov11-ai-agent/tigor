# %%
# https://solvespace.com/index.pl

# %%
x = [[0, 35],
 [0, 89],
 [59, 155],
 [105, 155],
 [105, 112],
 
 [684, 112],
 [684, 163],
 [769, 163],
 [821, 112],
 [821, 39],
 [732, 39],
 [732, 0],
 
 [732, -151],
 [634, -151],
 [634, 0],
 
 [593, 0],
 [593, -151],
 [495, -151],
 [495, 0],
 
 [454, 0],
 [454, -151],
 [356, -151],
 [356, 0],
 
 [315, 0],
 [315, -151],
 [217, -151],
 [217, 0],
 
 [176, 0],
 [176, -151],
 [78, -151],

 [78, 0],
 [78, 35]]

minx = min([e[0] for e in x])
miny = min([e[1] for e in x])

for e in x:
    # e[0] -= minx
    # e[1] -= miny
    e[0] /= 40
    e[1] /= 40

x
